# %%
import pandas as pd
import openpyxl

# %%
def convert_to_csv(excel_file):
    """
    Since Excel files cannot be previewed on GitHub, it would be nice to have a CSV conversion on site.
    """
    # Get Excel Object
    datafile = pd.ExcelFile(excel_file)
    
    # Check sheets 
    sheets = extract_sheets(excel_file, sheet_general_name):
    csv_name = f"{excel_file.split('.')[0]}.csv"
    datafile.to_csv(csv_name, mode="w") # File will be overriden with the "w" mode.
    return csv_name
convert_to_csv('Counting_Cells.xlsx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [2], in <cell line: 9>()
#       7     datafile.to_csv(csv_name, mode="w") # File will be overriden with the "w" mode.
#       8     return csv_name
# ----> 9 convert_to_csv('Counting_Cells.xlsx')
#
# Input In [2], in convert_to_csv(excel_file)
#       5 datafile = pd.ExcelFile(excel_file)
#       6 csv_name = f"{excel_file.split('.')[0]}.csv"
# ----> 7 datafile.to_csv(csv_name, mode="w") # File will be overriden with the "w" mode.
#       8 return csv_name
#
# AttributeError: 'ExcelFile' object has no attribute 'to_csv'

# %%
dir(pd.ExcelFile)
# Out:
# ['ODFReader',
#  'OpenpyxlReader',
#  'PyxlsbReader',
#  'XlrdReader',
#  '__annotations__',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__fspath__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_engines',
#  'book',
#  'close',
#  'parse',
#  'sheet_names']
